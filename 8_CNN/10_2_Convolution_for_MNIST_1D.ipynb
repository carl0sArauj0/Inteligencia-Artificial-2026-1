# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(1, 15, 3, 2),
    nn.ReLU(),
    nn.Conv1d(15, 15, 3, 2),
    nn.ReLU(),
    nn.Conv1d(15, 15, 3, 2),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10)
)


def weights_init(m):
    if isinstance(m, (nn.Conv1d, nn.Linear)):
        nn.init.kaiming_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0)

model.apply(weights_init)


loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9)
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 48
#      44 model.apply(weights_init)
#      45
#      46
#      47 loss_function = nn.CrossEntropyLoss()
# ---> 48 optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9)
#      49 scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/optim/sgd.py:65, in SGD.__init__(self, params, lr, momentum, dampening, weight_decay, nesterov, maximize, foreach, differentiable, fused)
#      63 if nesterov and (momentum <= 0 or dampening != 0):
#      64     raise ValueError("Nesterov momentum requires a momentum and zero dampening")
# ---> 65 super().__init__(params, defaults)
#      67 if fused:
#      68     self._step_supports_amp_scaling = True
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/optim/optimizer.py:405, in Optimizer.__init__(self, params, defaults)
#     402     param_groups = [{"params": param_groups}]
#     404 for param_group in param_groups:
# --> 405     self.add_param_group(cast(dict, param_group))
#     407 # Allows _accelerator_graph_capture_health_check to rig a poor man's TORCH_WARN_ONCE in python,
#     408 # which I don't think exists
#     409 # https://github.com/pytorch/pytorch/issues/72948
#     410 self._warned_capturable_if_run_uncaptured = True
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_compile.py:47, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      45 disable_fn = getattr(fn, "__dynamo_disable", None)
#      46 if disable_fn is None:
# ---> 47     import torch._dynamo
#      49     # We can safely turn off functools.wraps here because the inner
#      50     # already wraps fn in the outer scope.
#      51     disable_fn = torch._dynamo.disable(fn, recursive, wrapping=False)
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_dynamo/__init__.py:13
#       1 """
#       2 TorchDynamo is a Python-level JIT compiler designed to make unmodified PyTorch programs faster.
#       3 TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python
#    (...)      8 seamlessly optimize PyTorch programs, including those using modern Python features.
#       9 """
#      11 import torch
# ---> 13 from . import (
#      14     aot_compile,
#      15     bytecode_debugger,
#      16     config,
#      17     convert_frame,
#      18     eval_frame,
#      19     functional_export,
#      20     resume_execution,
#      21 )
#      22 from .backends.registry import list_backends, lookup_backend, register_backend
#      23 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_dynamo/aot_compile.py:17
#      15 import torch
#      16 import torch.fx
# ---> 17 from torch._dynamo.convert_frame import GraphRuntimeEnv
#      18 from torch._dynamo.graph_utils import _graph_device_type
#      19 from torch._dynamo.package import SystemInfo
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:62
#      60 from torch._dynamo.callback import CallbackTrigger
#      61 from torch._dynamo.distributed import get_compile_pg
# ---> 62 from torch._dynamo.symbolic_convert import TensorifyState
#      63 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      64 from torch._logging import structured
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:62
#      59 from torch.fx.experimental.symbolic_shapes import guard_bool
#      60 from torch.utils._functools import cache_method
# ---> 62 from . import (
#      63     config,
#      64     exc,
#      65     graph_break_hints,
#      66     logging as torchdynamo_logging,
#      67     trace_rules,
#      68     variables,
#      69 )
#      70 from .bytecode_analysis import (
#      71     get_indexof,
#      72     JUMP_OPNAMES,
#      73     livevars_analysis,
#      74     propagate_line_nums,
#      75 )
#      76 from .bytecode_transformation import (
#      77     cleaned_instructions,
#      78     create_binary_slice,
#    (...)     92     unique_id,
#      93 )
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_dynamo/trace_rules.py:45
#      42 from typing import Any
#      44 import torch
# ---> 45 import torch._inductor.test_operators
#      46 import torch.distributed
#      47 import torch.utils._content_store
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_inductor/__init__.py:12
#       8 from typing import Any, IO, Literal, Optional, TYPE_CHECKING, Union
#      10 import torch.fx
# ---> 12 from .standalone_compile import CompiledArtifact, DynamicShapesType  # noqa: TC001
#      15 if TYPE_CHECKING:
#      16     from torch._inductor.utils import InputType
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_inductor/standalone_compile.py:19
#      17 from torch._dynamo.aot_compile_types import BundledAOTAutogradSerializableCallable
#      18 from torch._dynamo.utils import dynamo_timed
# ---> 19 from torch._inductor.cpp_builder import normalize_path_separator
#      20 from torch._inductor.cudagraph_utils import BoxedDeviceIndex
#      21 from torch._inductor.runtime.cache_dir_utils import temporary_cache_dir
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_inductor/cpp_builder.py:30
#      28 import torch
#      29 from torch._dynamo.utils import dynamo_timed
# ---> 30 from torch._inductor import config, exc
#      31 from torch._inductor.cpu_vec_isa import invalid_vec_isa, VecISA
#      32 from torch._inductor.runtime.runtime_utils import cache_dir
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_inductor/config.py:300
#     293 b2b_gemm_pass = False
#     295 # register custom graph optimization pass hook. so far, pre/post passes are
#     296 # only applied before/after pattern_matcher in post_grad_passes.
#     297 #
#     298 # Implement CustomGraphPass to allow Inductor to graph compiled artifacts
#     299 # to which your custom passes have been applied:
# --> 300 post_grad_custom_pre_pass: torch._inductor.custom_graph_pass.CustomGraphPassType = None
#     301 post_grad_custom_post_pass: torch._inductor.custom_graph_pass.CustomGraphPassType = None
#     303 # Allow users to pass in custom partition function
#
# AttributeError: partially initialized module 'torch._inductor' has no attribute 'custom_graph_pass' (most likely due to a circular import)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 4
#       1 # choose cross entropy loss function (equation 5.24 in the loss notes)
#       2 loss_function = nn.CrossEntropyLoss()
#       3 # construct SGD optimizer and initialize learning rate and momentum
# ----> 4 optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
#       5 # object that decreases learning rate by half every 20 epochs
#       6 scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
#       7 # create 100 dummy data points and store in data loader class
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/optim/sgd.py:65, in SGD.__init__(self, params, lr, momentum, dampening, weight_decay, nesterov, maximize, foreach, differentiable, fused)
#      63 if nesterov and (momentum <= 0 or dampening != 0):
#      64     raise ValueError("Nesterov momentum requires a momentum and zero dampening")
# ---> 65 super().__init__(params, defaults)
#      67 if fused:
#      68     self._step_supports_amp_scaling = True
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/optim/optimizer.py:405, in Optimizer.__init__(self, params, defaults)
#     402     param_groups = [{"params": param_groups}]
#     404 for param_group in param_groups:
# --> 405     self.add_param_group(cast(dict, param_group))
#     407 # Allows _accelerator_graph_capture_health_check to rig a poor man's TORCH_WARN_ONCE in python,
#     408 # which I don't think exists
#     409 # https://github.com/pytorch/pytorch/issues/72948
#     410 self._warned_capturable_if_run_uncaptured = True
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_compile.py:47, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      45 disable_fn = getattr(fn, "__dynamo_disable", None)
#      46 if disable_fn is None:
# ---> 47     import torch._dynamo
#      49     # We can safely turn off functools.wraps here because the inner
#      50     # already wraps fn in the outer scope.
#      51     disable_fn = torch._dynamo.disable(fn, recursive, wrapping=False)
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_dynamo/__init__.py:13
#       1 """
#       2 TorchDynamo is a Python-level JIT compiler designed to make unmodified PyTorch programs faster.
#       3 TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python
#    (...)      8 seamlessly optimize PyTorch programs, including those using modern Python features.
#       9 """
#      11 import torch
# ---> 13 from . import (
#      14     aot_compile,
#      15     bytecode_debugger,
#      16     config,
#      17     convert_frame,
#      18     eval_frame,
#      19     functional_export,
#      20     resume_execution,
#      21 )
#      22 from .backends.registry import list_backends, lookup_backend, register_backend
#      23 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_dynamo/aot_compile.py:17
#      15 import torch
#      16 import torch.fx
# ---> 17 from torch._dynamo.convert_frame import GraphRuntimeEnv
#      18 from torch._dynamo.graph_utils import _graph_device_type
#      19 from torch._dynamo.package import SystemInfo
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:62
#      60 from torch._dynamo.callback import CallbackTrigger
#      61 from torch._dynamo.distributed import get_compile_pg
# ---> 62 from torch._dynamo.symbolic_convert import TensorifyState
#      63 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      64 from torch._logging import structured
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:62
#      59 from torch.fx.experimental.symbolic_shapes import guard_bool
#      60 from torch.utils._functools import cache_method
# ---> 62 from . import (
#      63     config,
#      64     exc,
#      65     graph_break_hints,
#      66     logging as torchdynamo_logging,
#      67     trace_rules,
#      68     variables,
#      69 )
#      70 from .bytecode_analysis import (
#      71     get_indexof,
#      72     JUMP_OPNAMES,
#      73     livevars_analysis,
#      74     propagate_line_nums,
#      75 )
#      76 from .bytecode_transformation import (
#      77     cleaned_instructions,
#      78     create_binary_slice,
#    (...)     92     unique_id,
#      93 )
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_dynamo/trace_rules.py:45
#      42 from typing import Any
#      44 import torch
# ---> 45 import torch._inductor.test_operators
#      46 import torch.distributed
#      47 import torch.utils._content_store
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_inductor/__init__.py:12
#       8 from typing import Any, IO, Literal, Optional, TYPE_CHECKING, Union
#      10 import torch.fx
# ---> 12 from .standalone_compile import CompiledArtifact, DynamicShapesType  # noqa: TC001
#      15 if TYPE_CHECKING:
#      16     from torch._inductor.utils import InputType
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_inductor/standalone_compile.py:19
#      17 from torch._dynamo.aot_compile_types import BundledAOTAutogradSerializableCallable
#      18 from torch._dynamo.utils import dynamo_timed
# ---> 19 from torch._inductor.cpp_builder import normalize_path_separator
#      20 from torch._inductor.cudagraph_utils import BoxedDeviceIndex
#      21 from torch._inductor.runtime.cache_dir_utils import temporary_cache_dir
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_inductor/cpp_builder.py:30
#      28 import torch
#      29 from torch._dynamo.utils import dynamo_timed
# ---> 30 from torch._inductor import config, exc
#      31 from torch._inductor.cpu_vec_isa import invalid_vec_isa, VecISA
#      32 from torch._inductor.runtime.runtime_utils import cache_dir
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_inductor/config.py:1373
#    1369     return compile_threads
#    1372 # TODO: Set directly after internal rollout.
# -> 1373 compile_threads: int | None = None if is_fbcode() else decide_compile_threads()
#    1375 # Whether to quiesce the Triton-compile subprocess pool at the end of each compilation.
#    1376 quiesce_async_compile_pool: bool = Config(
#    1377     justknob="pytorch/inductor:quiesce_async_compile_pool",
#    1378     env_name_force="TORCHINDUCTOR_QUIESCE_ASYNC_COMPILE_POOL",
#    1379     default=True,
#    1380 )
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/_inductor/config.py:1364, in decide_compile_threads()
#    1362     log.info("compile_threads set to 1 in fbcode")
#    1363 else:
# -> 1364     cpu_count = torch._utils.cpu_count()
#    1365     assert cpu_count
#    1366     compile_threads = min(32, cpu_count)
#
# File ~/Documents/Github/Inteligencia-Artificial-2026-1/IA/lib/python3.12/site-packages/torch/__init__.py:2963, in __getattr__(name)
#    2960     warnings.warn(f"'{name}' is deprecated, please do not call", stacklevel=2)
#    2961     return lambda *args: None
# -> 2963 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute '_utils'
